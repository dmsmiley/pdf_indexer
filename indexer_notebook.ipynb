# %%
import PyPDF2

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
cachedSW = set(stopwords.words('english'))

import re

from spellchecker import SpellChecker
spell = SpellChecker(distance=1)

from collections import defaultdict

import pandas as pd

import spacy
nlp = spacy.load('en_core_web_sm')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dsmiley\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
d = defaultdict(list)

# %%
def append_value(dict_obj, key, value):
    # Check if key exist in dict or not
    if key in dict_obj:
        # Key exist in dict.
        # Check if type of value of key is list or not
        if not isinstance(dict_obj[key], list):
            # If type is not list then make it list
            dict_obj[key] = [dict_obj[key]]
        # Append the value in list
        dict_obj[key].append(value)
    else:
        # As key is not in dict,
        # so, add key-value pair
        dict_obj[key] = value

def open_text(pdf_file):
  pdf = open(pdf_file, 'rb')
  pdf_reader = PyPDF2.PdfFileReader(pdf)
  return pdf_reader


def clean_text_list(reader_file, pdf_page=1):

  page = reader_file.getPage(pdf_page)
    
  text = page.extractText().replace('\n','')
  
  text_main = re.split(r"[0-9]\.", text, 1)[0]

  text_main = re.sub(r'[0-9]', '', text_main)
  text_main = re.sub(r'([^\s\w]|_)+', '', text_main)
  text_main = text_main.lower()

  text_main = text_main.split()

  cleaned_text = []

  for x in text_main:
    if x not in cachedSW:
      cleaned_text.append(x)

  corrected_text = [spell.correction(word) for word in cleaned_text]

  corrected_text = set(corrected_text)
  return corrected_text

def loop_all_pages(pdf, dictionary, pdf_page=1, book_page=1, pdf_end=1):
  pdf_reader = open(pdf, 'rb')
  pdf_reader = PyPDF2.PdfFileReader(pdf)
  pdf_count = pdf_page
  book_count = book_page

  for x in pdf_reader.getPage(pdf_count):
    if pdf_count == pdf_end:
      break
    else:
      corrected_text = clean_text_list(pdf_reader, pdf_page=pdf_count)
      page_difference = pdf_count - book_count
      new_value = pdf_count - page_difference
      for word in corrected_text:
        append_value(dictionary, word, new_value)
      pdf_count += 1
      book_count += 1
    return dictionary

# %%
pdf = #insert file here

# %%
starting_pdf_page = #pdf page

displayed_book_page = #book page

ending_pdf_page = #pdf page

loop_all_pages(pdf, d, starting_pdf_page, displayed_book_page, ending_pdf_page)
# Out:
# defaultdict(list,
#             {'remain': 7,
#              'abundance': 7,
#              'rest': 7,
#              'orderly': 7,
#              'feeling': 7,
#              'way': 7,
#              'need': 7,
#              'prolegomenaspeak': 7,
#              'sort': 7,
#              'resulting': 7,
#              'things': 7,
#              'examine': 7,
#              'speculative': 7,
#              'systematic': 7,
#              'phenomena': 7,
#              'sight': 7,
#              'serves': 7,
#              'precisely': 7,
#              'believe': 7,
#              'wordtheology': 7,
#              'faithknowledge': 7,
#              'task': 7,
#              'revealed': 7,
#              'say': 7,
#              'divine': 7,
#              'apart': 7,
#              'world': 7,
#              'words': 7,
#              'happy': 7,
#              'attempted': 7,
#              'loses': 7,
#              'summarize': 7,
#              'accordance': 7,
#              'also': 7,
#              'means': 7,
#              'god': 7,
#              'someone': 7,
#              'call': 7,
#              'truth': 7,
#              'dogmatic': 7,
#              'substitute': 7,
#              'relationship': 7,
#              'know': 7,
#              'question': 7,
#              'well': 7,
#              'knowledge': 7,
#              'intellect': 7,
#              'scientific': 7,
#              'ask': 7,
#              'develops': 7,
#              'heart': 7,
#              'like': 7,
#              'godly': 7,
#              'sense': 7,
#              'facts': 7,
#              'objectively': 7,
#              'known': 7,
#              'comes': 7,
#              'however': 7,
#              'objections': 7,
#              'bracket': 7,
#              'relation': 7,
#              'christian': 7,
#              'word': 7,
#              'concerns': 7,
#              'life': 7,
#              'creatures': 7,
#              'external': 7,
#              'church': 7,
#              'dierent': 7,
#              'moral': 7,
#              'conduct': 7,
#              'matter': 7,
#              'objection': 7,
#              'personal': 7,
#              'avoid': 7,
#              'insist': 7,
#              'examination': 7,
#              'confuses': 7,
#              'system': 7,
#              'idea': 7,
#              'object': 7,
#              'deeds': 7,
#              'speculation': 7,
#              'consciousness': 7,
#              'true': 7,
#              'raised': 7,
#              'come': 7,
#              'possible': 7,
#              'reason': 7,
#              'grave': 7,
#              'objectors': 7,
#              'everyone': 7,
#              'nature': 7,
#              'aim': 7,
#              'right': 7,
#              'cannot': 7,
#              'objective': 7,
#              'claim': 7,
#              'us': 7,
#              'empirical': 7,
#              'knowable': 7,
#              'appreciate': 7,
#              'creates': 7,
#              'place': 7,
#              'rationalistic': 7,
#              'evidence': 7,
#              'faculty': 7,
#              'data': 7,
#              'e': 7,
#              'must': 7,
#              'categories': 7,
#              'cut': 7,
#              'evangelical': 7,
#              'stand': 7,
#              'theology': 7,
#              'transcript': 7,
#              'subjective': 7,
#              'speak': 7,
#              'perception': 7,
#              'real': 7,
#              'manner': 7,
#              'autonomous': 7,
#              'gain': 7,
#              'today': 7,
#              'exist': 7,
#              'ie': 7,
#              'made': 7,
#              'objects': 7,
#              'understandable': 7,
#              'faith': 7,
#              'concerning': 7,
#              'much': 7,
#              'science': 7,
#              'always': 7,
#              'quite': 7,
#              'convinces': 7,
#              'source': 7,
#              'investigation': 7,
#              'whole': 7,
#              'understanding': 7,
#              'exists': 7,
#              'marshaled': 7,
#              'truly': 7,
#              'christ': 7,
#              'head': 7,
#              'revelation': 7,
#              'faculties': 7,
#              'viewpoint': 7,
#              'history': 7,
#              'frame': 7})

# %%
df = pd.DataFrame([(k, v) for k, v in d.items()], 
                   columns=['word', 'pages'])

# %%
df
# Out:
#            word  pages
# 0        remain      7
# 1     abundance      7
# 2          rest      7
# 3       orderly      7
# 4       feeling      7
# ..          ...    ...
# 146  revelation      7
# 147   faculties      7
# 148   viewpoint      7
# 149     history      7
# 150       frame      7
#
# [151 rows x 2 columns]
